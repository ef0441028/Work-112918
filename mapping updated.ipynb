# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)
from astropy.utils.data import get_pkg_data_filename
import os
import shutil
from astropy.table import QTable
import matplotlib.colors
from matplotlib.mlab import bivariate_normal
import csv
import pandas as pd

# %%
t_all = QTable.read('2throughput_merged_data_all.csv', format='ascii.csv')
t_21 = QTable.read('2throughput_merged_data_21.csv', format='ascii.csv')
t_22 = QTable.read('2throughput_merged_data_22.csv', format='ascii.csv')
t_23 = QTable.read('2throughput_merged_data_23.csv', format='ascii.csv')
t_24 = QTable.read('2throughput_merged_data_24.csv', format='ascii.csv')
t_25 = QTable.read('2throughput_merged_data_25.csv', format='ascii.csv')
t_test = QTable.read('3throughput_merged_data_21.csv', format='ascii.csv')

# %%
x = t_all['X']
y = t_all['Y']
z = t_all['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

fig.tight_layout()
colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=20, cmap=colormap, norm=normalize)

# %%
x = t_21['X']
y = t_21['Y']
z = t_21['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=20, cmap=colormap, norm=normalize)

# %%
x = t_22['X']
y = t_22['Y']
z = t_22['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=25, cmap=colormap, norm=normalize)

# %%
x = t_23['X']
y = t_23['Y']
z = t_23['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=25, cmap=colormap, norm=normalize)

# %%
x = t_24['X']
y = t_24['Y']
z = t_24['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=25, cmap=colormap, norm=normalize)

# %%
x = t_25['X']
y = t_25['Y']
z = t_25['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=25, cmap=colormap, norm=normalize)

# %%
import numpy
data = np.array(t_21['X'])
bins = numpy.linspace(-300, 300, 6)
digitized = numpy.digitize(data, bins)
bin_means = [data[digitized == i].mean() for i in range(1, len(bins))]
print(bin_means)
# Out:
# [-219.40410422935219, -116.99760681710768, 0.9279136816943602, 116.40150673122166, 220.9462190874036]

# %%
x = t_21['X']
print (x)
# Out:
#     X
# ----------
#  29.303837
#  11.941195
#  25.778107
#   51.04177
# -9.9939776
#   14.01632
#  165.20955
#  132.82402
#  127.22854
#   86.48996
#        ...
# -206.07399
# -258.54449
# -242.92652
# -207.95488
# -222.91023
# -275.07085
# -292.67228
# -309.10619
# -272.99556
#   -271.101
# -272.04031
# Length = 56944 rows

# %%
#compares throughput fiber number and plate, writes throughput to new csv with all relevant data if matched
def main(): 

    throughput = 'C:/Users/farre/Documents/dome flats south/21/throughput.csv'
    mapdatatest = 'C:/Users/farre/Documents/dome flats south/21/extracted_data_final.csv'
    outputfile = "output"

    with open(throughput, 'r') as master:
        wtr = csv.writer(open ("2throughput_merged_data_21.csv", 'a'), delimiter=',', lineterminator='\n')
        reader = csv.reader(master)
        for row in reader: 
            
            with open(mapdatatest, 'r') as data: 
                datafile = csv.reader(data)
                for rows in datafile:
                    if rows[0] in row and rows[5] in row:
                        for item in rows:
                            if item not in row: row.append(item)  
                    
                        wtr.writerow(row)
						# rows.extend(row)
						# print(unique_justseen(rows))

if __name__ == "__main__":
    main()
# Out:
# 15.343166
# 15.327964
# 15.290421
# 15.230452
# 15.225351
# 15.312291
# 15.450581
# 15.37389
# 15.303278
# 15.317284
# 15.339235
# 15.360908
# 15.534995
# 15.51716
# 15.559741
# 15.504467
# 15.548233
# 15.440907
# 15.54326
# 15.51959
# 15.527654
# 15.319807
# 15.498639
# 15.427192
# 15.600908
# 15.617456
# 15.619353
# 15.55238
# 15.558807
# 15.504739
# 16.413286
# 16.346313
# 16.444028
# 16.34462
# 16.390408
# 16.436506
# 16.240908
# 16.31876
# 16.197421
# 16.244042
# 16.148778
# 16.059543
# 15.963861
# 15.96063
# 15.91876
# 15.931653
# 15.825447
# 15.825681
# 16.053173
# 16.03116
# 16.02031
# 15.927387
# 15.973775
# 15.964558
# 15.780908
# 15.785212
# 15.770527
# 15.688017
# 15.701164
# 15.760908
# 16.700909
# 17.061134
# 17.080618
# 16.89225
# 16.780304
# 16.800907
# 16.953708
# 16.898663
# 16.922895
# 16.861862
# 16.667995
# 16.944404
# 16.720907
# 16.874699
# 16.786489
# 16.763301
# 16.810343
# 16.700909
# 16.611731
# 16.575867
# 16.545158
# 16.521018
# 16.532472
# 16.489652
# ...

# %%
df = pd.read_csv('3throughput_merged_data_21.csv')
a = df.loc[df['X'] >= 300]
print(a)
# Out:
#                    ID  Fiber#  Throughput          RA        DEC          X  \
# 56841  11169-58438-01     248    1.032380   79.571327 -67.012794  300.03086
# 56842  10574-58348-01     267    1.040975  284.270140 -31.275997  300.31902
# 56843  10575-58383-01     291    0.972862  284.270140 -31.275997  300.31902
# 56844   9941-58059-01     135    0.914580  271.990310 -28.194288  300.56288
# 56845  10007-58032-02     135    0.890640   59.402014  16.041456  300.59418
# 56846  10131-58291-01     297    0.977852    3.032374 -72.106971  300.77879
# 56847  10131-58322-01     279    0.944169    3.032374 -72.106971  300.77879
# 56848  10133-58356-01     249    1.082175    3.032374 -72.106971  300.77879
# 56849  10135-58443-01     249    1.086474    3.032374 -72.106971  300.77879
# 56850  10136-58418-01     268    0.985237    3.032374 -72.106971  300.77879
# 56851   9955-58263-02     255    0.981247  265.568020 -21.725964  301.02401
# ...
