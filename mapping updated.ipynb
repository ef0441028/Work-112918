# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)
from astropy.utils.data import get_pkg_data_filename
import os
import shutil
from astropy.table import QTable
import matplotlib.colors
from matplotlib.mlab import bivariate_normal
import csv
import pandas as pd

# %%
t_all = QTable.read('2throughput_merged_data_all.csv', format='ascii.csv')
t_21 = QTable.read('2throughput_merged_data_21.csv', format='ascii.csv')
t_22 = QTable.read('2throughput_merged_data_22.csv', format='ascii.csv')
t_23 = QTable.read('2throughput_merged_data_23.csv', format='ascii.csv')
t_24 = QTable.read('2throughput_merged_data_24.csv', format='ascii.csv')
t_25 = QTable.read('2throughput_merged_data_25.csv', format='ascii.csv')
t_test = QTable.read('3throughput_merged_data_21.csv', format='ascii.csv')

# %%
x = t_all['X']
y = t_all['Y']
z = t_all['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

fig.tight_layout()
colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=20, cmap=colormap, norm=normalize)

# %%
x = t_21['X']
y = t_21['Y']
z = t_21['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=20, cmap=colormap, norm=normalize)

# %%
x = t_22['X']
y = t_22['Y']
z = t_22['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=25, cmap=colormap, norm=normalize)

# %%
x = t_23['X']
y = t_23['Y']
z = t_23['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=25, cmap=colormap, norm=normalize)

# %%
x = t_24['X']
y = t_24['Y']
z = t_24['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=25, cmap=colormap, norm=normalize)

# %%
x = t_25['X']
y = t_25['Y']
z = t_25['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=25, cmap=colormap, norm=normalize)

# %%
df = pd.read_csv('3throughput_merged_data_21.csv')
#a = df.loc[df['X'] >= 300]

df[(df['X'] >= 300) & (df['X'] <= 315)]
df[(df['X'] >= 290) & (df['X'] <= 300)]
df[(df['X'] >= 280) & (df['X'] <= 290)]
df[(df['X'] >= 270) & (df['X'] <= 280)]
df[(df['X'] >= 260) & (df['X'] <= 270)]
df[(df['X'] >= 250) & (df['X'] <= 260)]
df[(df['X'] >= 240) & (df['X'] <= 250)]
df[(df['X'] >= 230) & (df['X'] <= 240)]
df[(df['X'] >= 220) & (df['X'] <= 230)]
df[(df['X'] >= 210) & (df['X'] <= 220)]
df[(df['X'] >= 200) & (df['X'] <= 210)]
df[(df['X'] >= 190) & (df['X'] <= 200)]
df[(df['X'] >= 180) & (df['X'] <= 190)]
df[(df['X'] >= 170) & (df['X'] <= 180)]
df[(df['X'] >= 160) & (df['X'] <= 170)]
df[(df['X'] >= 150) & (df['X'] <= 160)]
df[(df['X'] >= 140) & (df['X'] <= 150)]
df[(df['X'] >= 130) & (df['X'] <= 140)]
df[(df['X'] >= 120) & (df['X'] <= 130)]
df[(df['X'] >= 110) & (df['X'] <= 120)]
df[(df['X'] >= 100) & (df['X'] <= 110)]
df[(df['X'] >= 90) & (df['X'] <= 100)]
df[(df['X'] >= 80) & (df['X'] <= 90)]
df[(df['X'] >= 70) & (df['X'] <= 80)]
df[(df['X'] >= 60) & (df['X'] <= 70)]
df[(df['X'] >= 50) & (df['X'] <= 60)]
df[(df['X'] >= 40) & (df['X'] <= 50)]
df[(df['X'] >= 30) & (df['X'] <= 40)]
df[(df['X'] >= 20) & (df['X'] <= 30)]
df[(df['X'] >= 10) & (df['X'] <= 20)]
df[(df['X'] >= 0) & (df['X'] <= 10)]
df[(df['X'] >= -315) & (df['X'] <= -300)]
df[(df['X'] >= -300) & (df['X'] <= -290)]
df[(df['X'] >= -290) & (df['X'] <= -280)]
df[(df['X'] >= -280) & (df['X'] <= -270)]
df[(df['X'] >= -270) & (df['X'] <= -260)]
df[(df['X'] >= -260) & (df['X'] <= -250)]
df[(df['X'] >= -250) & (df['X'] <= -240)]
df[(df['X'] >= -240) & (df['X'] <= -230)]
df[(df['X'] >= -230) & (df['X'] <= -220)]
df[(df['X'] >= -220) & (df['X'] <= -210)]
df[(df['X'] >= -210) & (df['X'] <= -200)]
df[(df['X'] >= -200) & (df['X'] <= -190)]
df[(df['X'] >= -190) & (df['X'] <= -180)]
df[(df['X'] >= -180) & (df['X'] <= -170)]
df[(df['X'] >= -170) & (df['X'] <= -160)]
df[(df['X'] >= -160) & (df['X'] <= -150)]
df[(df['X'] >= -150) & (df['X'] <= -140)]
df[(df['X'] >= -140) & (df['X'] <= -130)]
df[(df['X'] >= -130) & (df['X'] <= -120)]
df[(df['X'] >= -120) & (df['X'] <= -110)]
df[(df['X'] >= -110) & (df['X'] <= -100)]
df[(df['X'] >= -100) & (df['X'] <= -90)]
df[(df['X'] >= -90) & (df['X'] <= -80)]
df[(df['X'] >= -80) & (df['X'] <= -70)]
df[(df['X'] >= -70) & (df['X'] <= -60)]
df[(df['X'] >= -60) & (df['X'] <= -50)]
df[(df['X'] >= -50) & (df['X'] <= -40)]
df[(df['X'] >= -40) & (df['X'] <= -30)]
# 28377  10178-58155-01      80    1.005310  186.174150 -62.456034 -0.179859
# 28378   9641-58210-02     234    1.104684  135.093980 -60.553715 -0.175202
# 28379  10107-58445-01     178    0.939218   73.185038 -68.322574 -0.152741
# 28380  10082-58027-01     241    0.923906   10.495177 -67.363667 -0.141455
# 28381  10124-58329-02      79    1.036462   10.495178 -67.363667 -0.141431
# 28382  10124-58358-01      67    1.139810   10.495178 -67.363667 -0.141431
# 28383  10178-58155-01      76    1.055455  186.173780 -62.142742 -0.125038
# 28384  10670-58297-02     184    0.765687  251.167490 -19.359408 -0.093231
# 28385   9451-58152-03       6    1.192578   97.514794 -31.813272 -0.082338
# 28386  10113-58447-01     191    0.775379   80.601674 -69.869103 -0.065059
# 28387  10426-58207-01     217    0.000000   97.514782 -31.813249 -0.063664
# 28388   9736-58060-02     241    0.884013   81.061614 -23.833975 -0.058715
# 28389   9735-58033-01     242    1.024560   81.061614 -23.833975 -0.041196
# 28390   9735-58033-01     242    1.024560   81.061614 -23.833975 -0.041196
# 28391  10593-58242-02      84    0.810150  246.615810 -24.445070 -0.033049
# 28392  10710-58269-01      67    1.154548  176.203490 -14.372551 -0.031945
# 28393  10710-58273-01      79    1.152663  176.203490 -14.372551 -0.031945
# 28394  10710-58290-01      72    0.987332  176.203490 -14.372551 -0.031945
# 28395  10711-58291-01      79    1.154582  176.203490 -14.372551 -0.031945
# 28396  10712-58275-01      83    1.115641  176.203490 -14.372551 -0.031945
# 28397  10712-58292-01      80    1.033771  176.203490 -14.372551 -0.031945
# 28398  10112-58096-01      45    0.975956   79.932294 -72.669623 -0.026554
# 28399  10174-58145-02      47    1.027783  157.786120 -58.204481 -0.015617
#
#                 Y
# 27159  167.434560
# 27160  167.434560
# 27161  306.000300
# 27162 -247.093770
# 27163  -77.858851
# 27164  -52.586175
# 27165  -52.585930
# 27166 -184.532480
# 27167  -45.204032
# 27168  -45.204032
# 27169  237.001090
# 27170  -75.054929
# 27171  -75.054929
# 27172  -75.054929
# 27173 -236.645140
# 27174 -184.008560
# 27175 -303.944410
# 27176  291.631600
# 27177  251.695020
# 27178 -141.735520
# 27179   73.818355
# 27180  107.419040
# 27181   41.322012
# 27182  132.644580
# 27183  204.410690
# 27184  200.808600
# 27185  154.933470
# 27186 -188.296160
# 27187 -138.768070
# 27188 -104.826610
# ...           ...
# 28370  260.513120
# 28371  141.510700
# 28372  117.484250
# 28373  199.004010
# 28374  199.004010
# 28375  199.004010
# 28376 -287.455360
# 28377 -131.864440
# 28378  191.056960
# 28379 -158.604040
# 28380 -129.595750
# 28381 -129.596480
# 28382 -129.596480
# 28383 -235.649060
# 28384   78.893178
# 28385  123.911810
# 28386   52.347272
# 28387  123.903710
# 28388 -176.150960
# 28389 -176.148170
# 28390 -176.148170
# 28391 -196.413960
# 28392 -159.214960
# 28393 -159.214960
# 28394 -159.214960
# 28395 -159.214960
# 28396 -159.214960
# 28397 -159.214960
# 28398  -48.740056
# 28399   51.151661
#
# [1241 rows x 7 columns]
