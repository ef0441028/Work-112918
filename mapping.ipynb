# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)
from astropy.utils.data import get_pkg_data_filename
import os
import shutil
from astropy.table import QTable
import matplotlib.colors
from matplotlib.mlab import bivariate_normal

# %%
t_all = QTable.read('throughput_merged_data_all.csv', format='ascii.csv')
t_21 = QTable.read('throughput_merged_data_21.csv', format='ascii.csv')
t_22 = QTable.read('throughput_merged_data_22.csv', format='ascii.csv')
t_23 = QTable.read('throughput_merged_data_23.csv', format='ascii.csv')
t_24 = QTable.read('throughput_merged_data_24.csv', format='ascii.csv')
t_25 = QTable.read('throughput_merged_data_25.csv', format='ascii.csv')

# %%
x = t_all['X']
y = t_all['Y']
z = t_all['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

fig.tight_layout()
colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=20, cmap=colormap, norm=normalize)

# %%
x = t_21['X']
y = t_21['Y']
z = t_21['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=20, cmap=colormap, norm=normalize)

# %%
x = t_22['X']
y = t_22['Y']
z = t_22['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=25, cmap=colormap, norm=normalize)

# %%
x = t_23['X']
y = t_23['Y']
z = t_23['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=25, cmap=colormap, norm=normalize)

# %%
x = t_24['X']
y = t_24['Y']
z = t_24['Throughput']
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)

colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=25, cmap=colormap, norm=normalize)

# %%
x = t_25['X']
y = t_25['Y']
z = t_25['Throughput']
total_bins = 10
fig,ax = plt.subplots(1,1)
fig.set_size_inches(11,8.5)
bins = np.geomspace(z.min(0.001), z.max(1.5), total_bins)
colormap = plt.cm.bwr #or any other colormap
normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
plt.scatter(x, y, c=z, s=25, cmap=colormap, norm=normalize)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-49c744570209> in <module>()
#       5 fig,ax = plt.subplots(1,1)
#       6 fig.set_size_inches(11,8.5)
# ----> 7 bins = np.geomspace(z.min(0.001), z.max(1.5), total_bins)
#       8 colormap = plt.cm.bwr #or any other colormap
#       9 normalize = matplotlib.colors.Normalize(vmin=-1, vmax=1)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
# ---> 29     return umr_minimum(a, axis, None, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
import numpy as np

chl  = np.array('t_21')

bins = np.array([0,50,100,150,200,250])

A = np.vstack((np.digitize, chl)).T

res = {bins[int(i)]: np.mean(A[A[:, 0] == i, 1]) for i in np.unique(A[:, 0])}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-1d156399f242> in <module>()
#       5 bins = np.array([0,50,100,150,200,250])
#       6
# ----> 7 A = np.vstack((np.digitize(bins), chl)).T
#       8
#       9 res = {bins[int(i)]: np.mean(A[A[:, 0] == i, 1]) for i in np.unique(A[:, 0])}
#
# TypeError: Required argument 'bins' (pos 2) not found

# %%
plt.figure()
plt.hist(z, bins=20, density=True, histtype='stepfilled',
         alpha=0.2, label='histogram of data')
plt.plot(x ,y, c=z, label='analytical pdf')
plt.hlines(bin_means, bin_edges[:-1], bin_edges[1:], colors='g', lw=2,
           label='binned statistic of data')
plt.plot((binnumber - 0.5) * bin_width, y, 'g.', alpha=0.5)
plt.legend(fontsize=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-f8567504ae69> in <module>()
#       3          alpha=0.2, label='histogram of data')
#       4 plt.plot(x ,y, c=z, label='analytical pdf')
# ----> 5 plt.hlines(bin_means, bin_edges[:-1], bin_edges[1:], colors='g', lw=2,
#       6            label='binned statistic of data')
#       7 plt.plot((binnumber - 0.5) * bin_width, y, 'g.', alpha=0.5)
#
# NameError: name 'bin_edges' is not defined
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000001863B043950> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     165     try:
# ...

# %%
import numpy
data = t_21['Throughput']
bins = numpy.linspace(0,50,100)
digitized = numpy.digitize(data, bins)
bin_means = [data[digitized == i].mean() for i in range(1, len(bins))]
print(bin_means)
# Out:
# [0.10637404909518214, 0.8812659273948792, 1.1062844612720086, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked]
